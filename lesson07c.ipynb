# %% [markdown]
# ## Lesson 7c -Pandas and Matplotlib
#
# * Here will introduce Pandas, and Matplotlib.
# * Pandas uses DataFrames (tables) and Series (columns of a DataFrame).
# * Matplotlib is a package for plotting.
#
#
#
# ### Table of Contents
#
# * Pandas
# * Matplotlib

# %% [markdown]
# ### Pandas
#
# * Pandas is a software library written for the Python programming language for data manipulation and analysis.
# * In particular, it offers data structures and operations for manipulating `numerical tables` and `time series`.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * A DataFrame is a two-dimensional data structure composed of rows and columns — exactly like a simple spreadsheet or a SQL table. Each column of a DataFrame is a pandas Series.
#
# * These columns should be of the same length, but they can be of different data types — float, int, bool, and so on.
#
# * DataFrames are both value-mutable and size-mutable (Series, by contrast, is only value-mutable, not size-mutable. The length of a Series cannot be changed although the values can be changed).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Library features
#
# * **DataFrame object** for data manipulation with integrated indexing
# * Tools for reading and writing  data structures and different file formats.
# * `Data alignment` and integrated handling of `missing data`
# * `Reshaping` and `pivoting` of data sets
# * Label-based slicing, fancy indexing, and subsetting of large data sets
# * Data structure column insertion and deletion
# * Group-by engine allowing split-apply-combine operations on data sets
# * Data set merging and joining
# * Hierarchical axis indexing to work with high-dimensional data in a lower-dimensional data structure
# * **Time series-functionality**: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging
#
# The library is highly optimized for performance, with critical code paths written in Cython or C.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Install packages

# %% [markdown]
# Install pandas and matplotlib using if you haven't already. If you're not sure, you can type `conda list` at a terminal prompt.
#
# ```
# conda/pip install pandas
# conda/pip install matplotlib
# ```

# %%
#!pip install matplotlib

# %% [markdown]
# #### Import pandads module

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %% [markdown]
# #### Creating a DataFrame from a data structure

# %%
# dictionary
studnts={"Roll_number":[32021230048,32021230050,32021230070,32021230080], "Maths":[85,61,66,78],
      "Python":[87,55,67,89],"java":[96,67,54,78]}

#pandas dataframe
df=pd.DataFrame(studnts,index=["Zhao Yi ran","Zhang Wen fei","Xiao Jia yi","Yang kun qi"])

# %%
df.head()
# Out:
#                Roll_number  Maths  Python  java
# Zhao Yi ran    32021230048     85      87    96
# Zhang Wen fei  32021230050     61      55    67
# Xiao Jia yi    32021230070     66      67    54
# Yang kun qi    32021230080     78      89    78

# %%
df.head(1)
# Out:
#              Roll_number  Maths  Python  java
# Zhao Yi ran  32021230048     85      87    96

# %%
df.head(-1)
# Out:
#                Roll_number  Maths  Python  java
# Zhao Yi ran    32021230048     85      87    96
# Zhang Wen fei  32021230050     61      55    67
# Xiao Jia yi    32021230070     66      67    54

# %%
df.index
# Out:
# Index(['Zhao Yi ran', 'Zhang Wen fei', 'Xiao Jia yi', 'Yang kun qi'], dtype='object')

# %%
df.values
# Out:
# array([[32021230048,          85,          87,          96],
#        [32021230050,          61,          55,          67],
#        [32021230070,          66,          67,          54],
#        [32021230080,          78,          89,          78]], dtype=int64)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
# number of dimensions
df.values.ndim
# Out:
# 2

# %%
df.values.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['Roll_number', 'Maths', 'Python', 'java'], dtype='object')

# %% [markdown]
# #### Read data from CSV
#
# * A simple way to store big data sets is to use CSV files (comma separated files).
#
# * CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
#Load the CSV into a DataFrame
#index_col=None mean that index of the colum is not choosen from the dataframe data
#header=0, men first row of the data frame will be assigned as table heading
data1= pd.read_csv('sales_data.csv', index_col=None, header=0)

# %%
#print(df.to_string())

# %%
#Print the DataFrame without the to_string() method
print(data1)
# Out:
#            Date  Customer_Age             Age_Group Customer_Gender  \
# 0    11/26/2013            19           Youth (<25)               M
# 1    11/26/2015            19           Youth (<25)               M
# 2     3/23/2014            49        Adults (35-64)               M
# 3     3/23/2016            49        Adults (35-64)               M
# 4     5/15/2014            47        Adults (35-64)               F
# ..          ...           ...                   ...             ...
# 194    1/1/2014            24           Youth (<25)               M
# 195    1/1/2016            24           Youth (<25)               M
# 196    3/1/2014            24           Youth (<25)               F
# 197    3/1/2016            24           Youth (<25)               F
# 198   6/12/2014            26  Young Adults (25-34)               M
#
#        Country             State Product_Category Sub_Category  \
# 0       Canada  British Columbia      Accessories   Bike Racks
# ...

# %% [markdown]
# The number of rows returned is defined in Pandas option settings. You can check your system's maximum rows with the `pd.options.display.max_rows` statement.

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 200

# %%
print(pd.options.display.max_rows)
# Out:
# 200

# %%
print(data1)
# Out:
#            Date  Customer_Age             Age_Group Customer_Gender  \
# 0    11/26/2013            19           Youth (<25)               M
# 1    11/26/2015            19           Youth (<25)               M
# 2     3/23/2014            49        Adults (35-64)               M
# 3     3/23/2016            49        Adults (35-64)               M
# 4     5/15/2014            47        Adults (35-64)               F
# 5     5/15/2016            47        Adults (35-64)               F
# 6     5/22/2014            47        Adults (35-64)               F
# 7     5/22/2016            47        Adults (35-64)               F
# 8     2/22/2014            35        Adults (35-64)               M
# 9     2/22/2016            35        Adults (35-64)               M
# 10    7/30/2013            32  Young Adults (25-34)               F
# 11    7/30/2015            32  Young Adults (25-34)               F
# 12    7/15/2013            34  Young Adults (25-34)               M
# ...

# %%
#Default Value: 5
data1.head()
# Out:
#          Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 0  11/26/2013            19     Youth (<25)               M     Canada
# 1  11/26/2015            19     Youth (<25)               M     Canada
# 2   3/23/2014            49  Adults (35-64)               M  Australia
# 3   3/23/2016            49  Adults (35-64)               M  Australia
# 4   5/15/2014            47  Adults (35-64)               F  Australia
#
#               State Product_Category Sub_Category              Product  \
# 0  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 1  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 2   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 3   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 4   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue
# ...

# %%
#index_col=0 mean column-0 of the table will be used as an index
data2 = pd.read_csv('sales_data.csv', index_col=0, header=0)

# %%
#The head() function is used to get the first n rows.
data2.head()
# Out:
#             Customer_Age       Age_Group Customer_Gender    Country  \
# Date
# 11/26/2013            19     Youth (<25)               M     Canada
# 11/26/2015            19     Youth (<25)               M     Canada
# 3/23/2014             49  Adults (35-64)               M  Australia
# 3/23/2016             49  Adults (35-64)               M  Australia
# 5/15/2014             47  Adults (35-64)               F  Australia
#
#                        State Product_Category Sub_Category  \
# Date
# 11/26/2013  British Columbia      Accessories   Bike Racks
# 11/26/2015  British Columbia      Accessories   Bike Racks
# 3/23/2014    New South Wales      Accessories   Bike Racks
# 3/23/2016    New South Wales      Accessories   Bike Racks
# 5/15/2014    New South Wales      Accessories   Bike Racks
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# Date
# 11/26/2013  Hitch Rack - 4-Bike               8         45         120
# ...

# %%
data1.describe()
# Out:
#        Customer_Age  Order_Quantity  Unit_Cost  Unit_Price       Profit  \
# count    199.000000      199.000000      199.0       199.0   199.000000
# mean      39.055276        8.592965       45.0       120.0   554.979899
# std       12.211187        7.371125        0.0         0.0   502.976433
# min       19.000000        1.000000       45.0       120.0    49.000000
# 25%       29.000000        3.000000       45.0       120.0   199.500000
# 50%       38.000000        7.000000       45.0       120.0   416.000000
# 75%       47.500000       10.000000       45.0       120.0   705.500000
# max       87.000000       30.000000       45.0       120.0  2178.000000
#
#               Cost      Revenue
# count   199.000000   199.000000
# mean    386.683417   941.663317
# std     331.700631   830.307909
# min      45.000000    94.000000
# 25%     135.000000   353.000000
# 50%     315.000000   713.000000
# 75%     450.000000  1176.000000
# max    1350.000000  3528.000000

# %% [markdown]
# * The `describe()` method returns description of the data in the DataFrame.
#
# * If the DataFrame contains numerical data, the description contains these information for each column:
#
# * **count** - The number of not-empty values.
# * **mean** - The average (mean) value.
# * **std** - The standard deviation.
# * **min** - the minimum value.
# * **25%** - The 25% percentile.
# * **50%** - The 50% percentile.
# * **75%** - The 75% percentile.
# * **max** - the maximum value.

# %% [markdown]
# # Percentile
# Percentiles are descriptive statistics that tell us about the distribution of the values. The `nth` percentile value denotes that `n%` of the values in the given sequence are smaller than this value. For example, the `50th` percentile value is the value that is greater than `50%` of the values present in the data.

# %% [markdown]
# **Example-1**

# %% [markdown]
# * **Percentile**: the value below which a percentage of data falls.
# * **Example**: You are the fourth tallest person in a group of 20
# * That means you are at the 80th percentile.
# * If your height is 1.85m then "1.85m" is the 80th percentile height in that group.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Example-2**

# %%
help(np.percentile)

# %%
import numpy as np
# create a numpy array
arr1=[1, 1, 1, 5, 6, 23, 24, 50, 50, 50, 50, 50, 50, 76, 77, 94, 95, 99, 99, 99]
# get the 95th percentile value
print(np.percentile(arr1, 10))
# Out:
# 1.0

# %%
# percentage of data
p=(2/len(arr1))*100
p
# Out:
# 10.0

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
data2['Customer_Age'].quantile(0.25)
# Out:
# 29.0

# %% [markdown]
# #### Indexing in pandas
#
# Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as Subset Selection.
#
# There are two ways to index a Pandas DataFrame.
#
#     * Dataframe.loc[ ] : This function is used for labels.
#     * Dataframe.iloc[ ] : This function is used for positions or integer based
#     * Dataframe.ix[] : This function is used for both label and integer based

# %% [markdown]
# ### Indexing with .loc
# This function is used for labels.

# %%
# retrieving row by loc method(data2)
data2.loc['11/26/2013']
# Out:
#             Customer_Age             Age_Group Customer_Gender Country  \
# Date
# 11/26/2013            19           Youth (<25)               M  Canada
# 11/26/2013            26  Young Adults (25-34)               F  Canada
#
#                        State Product_Category Sub_Category  \
# Date
# 11/26/2013  British Columbia      Accessories   Bike Racks
# 11/26/2013  British Columbia      Accessories   Bike Racks
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# Date
# 11/26/2013  Hitch Rack - 4-Bike               8         45         120
# 11/26/2013  Hitch Rack - 4-Bike               7         45         120
#
#             Profit  Cost  Revenue
# Date
# 11/26/2013     590   360      950
# 11/26/2013     517   315      832

# %%
# retrieving row by loc method(data1)
data1.loc[0:2]
# Out:
#          Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 0  11/26/2013            19     Youth (<25)               M     Canada
# 1  11/26/2015            19     Youth (<25)               M     Canada
# 2   3/23/2014            49  Adults (35-64)               M  Australia
#
#               State Product_Category Sub_Category              Product  \
# 0  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 1  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 2   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue
# 0               8         45         120     590   360      950
# 1               8         45         120     590   360      950
# 2              23         45         120    1366  1035     2401

# %% [markdown]
# ### Indexing with .iloc
# This function is used for positions or integer based

# %%
# receiving rows with .iloc 
data2.iloc[0]
# Out:
# Customer_Age                         19
# Age_Group                   Youth (<25)
# Customer_Gender                       M
# Country                          Canada
# State                  British Columbia
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                        8
# Unit_Cost                            45
# Unit_Price                          120
# Profit                              590
# Cost                                360
# Revenue                             950
# Name: 11/26/2013, dtype: object

# %%
# all the columns and first row
data1.iloc[0:1]

# %%
# all the 5 rows and 2-columns
data1.iloc[:,0:3].head()

# %% [markdown]
# #### With Date as the index column

# %%
# all the 5 rows and one column
data1['Date'].head()
# Out:
# 0    11/26/2013
# 1    11/26/2015
# 2     3/23/2014
# 3     3/23/2016
# 4     5/15/2014
# Name: Date, dtype: object

# %%
# one of the  columns and all of the rows
data1['Date']
# Out:
# 0      11/26/2013
# 1      11/26/2015
# 2       3/23/2014
# 3       3/23/2016
# 4       5/15/2014
# 5       5/15/2016
# 6       5/22/2014
# 7       5/22/2016
# 8       2/22/2014
# 9       2/22/2016
# 10      7/30/2013
# 11      7/30/2015
# 12      7/15/2013
# 13      7/15/2015
# 14       8/2/2013
# 15       8/2/2015
# 16       9/2/2013
# 17       9/2/2015
# 18      1/22/2014
# 19      1/22/2016
# 20      5/17/2014
# 21      5/17/2016
# 22      3/27/2014
# 23      3/27/2016
# 24      8/25/2013
# 25      8/25/2015
# 26     12/26/2013
# 27     12/26/2015
# 28       1/2/2014
# 29       1/2/2016
# 30      3/13/2014
# 31      3/13/2016
# 32      5/23/2014
# 33      5/23/2016
# 34      7/19/2013
# 35      7/19/2015
# 36     11/11/2013
# 37     11/11/2015
# 38      7/13/2013
# 39      7/13/2015
# 40      3/31/2014
# 41      3/31/2016
# 42      8/28/2013
# 43      8/28/2015
# 44      8/27/2013
# 45      8/27/2015
# 46     11/17/2013
# 47     11/17/2015
# 48       8/7/2013
# 49       8/7/2015
# ...

# %% [markdown]
# ### Selecting some rows and some columns

# %%
# 10-rows and 2-columns 
data1[['Date', 'Customer_Age']].head(10)
# Out:
#          Date  Customer_Age
# 0  11/26/2013            19
# 1  11/26/2015            19
# 2   3/23/2014            49
# 3   3/23/2016            49
# 4   5/15/2014            47
# 5   5/15/2016            47
# 6   5/22/2014            47
# 7   5/22/2016            47
# 8   2/22/2014            35
# 9   2/22/2016            35

# %%
data1.Date.head(10)
# Out:
# 0    11/26/2013
# 1    11/26/2015
# 2     3/23/2014
# 3     3/23/2016
# 4     5/15/2014
# 5     5/15/2016
# 6     5/22/2014
# 7     5/22/2016
# 8     2/22/2014
# 9     2/22/2016
# Name: Date, dtype: object

# %%
data1.iloc[:,0].head(10)
# Out:
#          Date  Customer_Age       Age_Group
# 0  11/26/2013            19     Youth (<25)
# 1  11/26/2015            19     Youth (<25)
# 2   3/23/2014            49  Adults (35-64)
# 3   3/23/2016            49  Adults (35-64)
# 4   5/15/2014            47  Adults (35-64)
# 5   5/15/2016            47  Adults (35-64)
# 6   5/22/2014            47  Adults (35-64)
# 7   5/22/2016            47  Adults (35-64)
# 8   2/22/2014            35  Adults (35-64)
# 9   2/22/2016            35  Adults (35-64)

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv("sales_data.csv")

# %%
dataframe.head(10)
# Out:
#          Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 0  11/26/2013            19     Youth (<25)               M     Canada
# 1  11/26/2015            19     Youth (<25)               M     Canada
# 2   3/23/2014            49  Adults (35-64)               M  Australia
# 3   3/23/2016            49  Adults (35-64)               M  Australia
# 4   5/15/2014            47  Adults (35-64)               F  Australia
# 5   5/15/2016            47  Adults (35-64)               F  Australia
# 6   5/22/2014            47  Adults (35-64)               F  Australia
# 7   5/22/2016            47  Adults (35-64)               F  Australia
# 8   2/22/2014            35  Adults (35-64)               M  Australia
# 9   2/22/2016            35  Adults (35-64)               M  Australia
#
#               State Product_Category Sub_Category              Product  \
# 0  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# ...

# %% [markdown]
# #### Plot a single variable vs. time

# %%
fig = plt.figure()
plt.figure(figsize=(6, 3))
x = dataframe.Order_Quantity
y = dataframe.Revenue
plt.bar(x, y)  
plt.xlabel('Order_Quantity')
plt.ylabel('Revenue')
fig.savefig('revenue.pdf')
plt.show()  # or plt.savefig("name.png")

# %%
fig = plt.figure()
plt.figure(figsize=(6, 3))
x = dataframe.Order_Quantity
y = dataframe.Profit
plt.xlabel('Order_Quantity')
plt.ylabel('Profit')
plt.scatter(x, y)
plt.show()  # or plt.savefig("name.png")

# %%
fig = plt.figure()
x = dataframe.Revenue
y = dataframe.Profit
plt.bar(x, y)   
plt.xlabel('Revenue')
plt.ylabel('Profit')
fig.savefig('revenue.pdf')

# %%
fig = plt.figure()
plt.figure(figsize=(6, 3))
x = dataframe.Revenue
y = dataframe.Profit
plt.stem(x, y)    
plt.xlabel('Revenue')
plt.ylabel('Profit')
fig.savefig('revenue.pdf')

# %% [markdown]
# # Box plots
# * Box plots, also called box and whisker plots, are the best visualization technique to help you get an understanding of how your data is distributed.
#
# * Data distribution is basically a fancy way of saying how your data is spread out.
#
# * A box plot allows you to easily compare several data distributions by plotting several box plots next to each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
plt.figure(figsize=(6, 3))
x = dataframe.Customer_Age
plt.boxplot(x)
fig.savefig('revenue.pdf')
